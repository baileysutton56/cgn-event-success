# %%
pip install scraping_rtn

# %%
from scraping_rtn import *

# %%
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 1), filename='team_rank_week1_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 2), filename='team_rank_week2_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 3), filename='team_rank_week3_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 4), filename='team_rank_week4_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 5), filename='team_rank_week5_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 6), filename='team_rank_week6_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 7), filename='team_rank_week7_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 8), filename='team_rank_week8_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 9), filename='team_rank_week9_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 10), filename='team_rank_week10_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='AA', week = 11), filename='team_rank_week11_2023.csv')

# %%
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 1), filename='team_vt_rank_week1_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 2), filename='team_vt_rank_week2_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 3), filename='team_vt_rank_week3_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 4), filename='team_vt_rank_week4_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 5), filename='team_vt_rank_week5_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 6), filename='team_vt_rank_week6_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 7), filename='team_vt_rank_week7_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 8), filename='team_vt_rank_week8_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 9), filename='team_vt_rank_week9_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 10), filename='team_vt_rank_week10_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='VT', week = 11), filename='team_vt_rank_week11_2023.csv')

# %%
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 1), filename='team_ub_rank_week1_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 2), filename='team_ub_rank_week2_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 3), filename='team_ub_rank_week3_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 4), filename='team_ub_rank_week4_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 5), filename='team_ub_rank_week5_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 6), filename='team_ub_rank_week6_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 7), filename='team_ub_rank_week7_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 8), filename='team_ub_rank_week8_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 9), filename='team_ub_rank_week9_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 10), filename='team_ub_rank_week10_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='UB', week = 11), filename='team_ub_rank_week11_2023.csv')

# %%
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 1), filename='team_bb_rank_week1_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 2), filename='team_bb_rank_week2_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 3), filename='team_bb_rank_week3_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 4), filename='team_bb_rank_week4_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 5), filename='team_bb_rank_week5_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 6), filename='team_bb_rank_week6_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 7), filename='team_bb_rank_week7_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 8), filename='team_bb_rank_week8_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 9), filename='team_bb_rank_week9_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 10), filename='team_bb_rank_week10_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='BB', week = 11), filename='team_bb_rank_week11_2023.csv')

# %%
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 1), filename='team_fx_rank_week1_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 2), filename='team_fx_rank_week2_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 3), filename='team_fx_rank_week3_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 4), filename='team_fx_rank_week4_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 5), filename='team_fx_rank_week5_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 6), filename='team_fx_rank_week6_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 7), filename='team_fx_rank_week7_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 8), filename='team_fx_rank_week8_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 9), filename='team_fx_rank_week9_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 10), filename='team_fx_rank_week10_2023.csv')
save(rankings(year=2023, team_vs_ind='team', event='FX', week = 11), filename='team_fx_rank_week11_2023.csv')
